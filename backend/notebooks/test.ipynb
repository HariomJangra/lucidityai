# %%
import sys
sys.path.append("..")

from app.services.websearch import websearch
# Out:
# ...
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]

# %%
print(websearch("Who won 2026 West Bengal's Elections?"))
# Out:
# [1] https://indianexpress.com/article/india/west-bengal-assembly-election-results-2026-winners-constituency-wise-seat-wise-full-list-10665665/
# ...
